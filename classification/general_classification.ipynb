# %%
from pandas import read_csv as read
from pycaret.classification import *
from itertools import combinations
import csv
import pandas as pd

# %%
# %%capture
df = read('../data/initial_features_classification.csv')

# The number of subjects used in testing data. Should be set to 3 to match the data used in results.
COMBINATIONS = 3

combinations_list = list(combinations(df['subject'].unique(), COMBINATIONS))

# %%
train_general_df = pd.DataFrame()
test_general_df = pd.DataFrame()
feature_importance_general_df = pd.DataFrame()

for sub in combinations_list:  # EX: [(2, 3, 6)]
    # Split data into training and testing based on subject
    train = df[~df['subject'].isin(sub)]
    test = df[df['subject'].isin(sub)]

    clf = setup(data=train, target='rpe', ignore_features=['experimental_condition', 'subject', 'wrist_acc_time'], verbose=False)
    best = compare_models(sort='Accuracy', n_select=18)
    all = pull()
    all['test_set'] = str(sub)

    # Append trained model results to dataframe
    train_general_df = pd.concat([train_general_df, all], ignore_index=True)
    
    test_results = pd.DataFrame()
    for model in best:
        # Run models on test data
        test_result = predict_model(model, data=test, verbose=False)
        test_result_df = pull()
        test_result_df['Model'] = str(model).split('(')[0]
        test_result_df['test_set'] = str(sub)
        test_results = pd.concat([test_results, test_result_df], ignore_index=True)
        
        # Add feature importance of model to dataframe
        try:
            importance = pd.DataFrame({'Feature': get_config('X_train').columns, 'Value': abs(model.feature_importances_)}).sort_values(by='Value', ascending=False).reset_index(drop=True)
        except:
            try:
                importance = pd.DataFrame({'Feature': get_config('X_train').columns, 'Value': abs(model.coef_)}).sort_values(by='Value', ascending=False).reset_index(drop=True)
            except:
                importance = pd.DataFrame({'Feature': ['error'], 'Value': [0]})

        # Append feature importance to dataframe
        importance['Model'] = str(model).split('(')[0]
        importance['test_subjects'] = str(sub)
        feature_importance_general_df = pd.concat([feature_importance_general_df, importance], ignore_index=True)

    # Append test model results to dataframe
    test_general_df = pd.concat([test_general_df, test_results], ignore_index=True)

# Save dataframes to csv
train_general_df.to_csv(f'outputs/train_general.csv', index=False)
test_general_df.to_csv(f'outputs/test_general.csv', index=False)
feature_importance_general_df.to_csv(f'outputs/feature_importance_general.csv', index=False)
# Out:
# <style type="text/css">
# #T_9696d th {
#   text-align: left;
# }
# #T_9696d_row0_col0, #T_9696d_row0_col3, #T_9696d_row1_col0, #T_9696d_row1_col1, #T_9696d_row1_col2, #T_9696d_row1_col3, #T_9696d_row1_col4, #T_9696d_row1_col5, #T_9696d_row1_col6, #T_9696d_row1_col7, #T_9696d_row2_col0, #T_9696d_row2_col1, #T_9696d_row2_col2, #T_9696d_row2_col3, #T_9696d_row2_col4, #T_9696d_row2_col5, #T_9696d_row2_col6, #T_9696d_row2_col7, #T_9696d_row3_col0, #T_9696d_row3_col1, #T_9696d_row3_col2, #T_9696d_row3_col3, #T_9696d_row3_col4, #T_9696d_row3_col5, #T_9696d_row3_col6, #T_9696d_row3_col7, #T_9696d_row4_col0, #T_9696d_row4_col1, #T_9696d_row4_col2, #T_9696d_row4_col3, #T_9696d_row4_col4, #T_9696d_row4_col5, #T_9696d_row4_col6, #T_9696d_row4_col7, #T_9696d_row5_col0, #T_9696d_row5_col1, #T_9696d_row5_col2, #T_9696d_row5_col3, #T_9696d_row5_col4, #T_9696d_row5_col5, #T_9696d_row5_col6, #T_9696d_row5_col7, #T_9696d_row6_col0, #T_9696d_row6_col1, #T_9696d_row6_col2, #T_9696d_row6_col3, #T_9696d_row6_col4, #T_9696d_row6_col5, #T_9696d_row6_col6, #T_9696d_row6_col7, #T_9696d_row7_col0, #T_9696d_row7_col1, #T_9696d_row7_col2, #T_9696d_row7_col3, #T_9696d_row7_col4, #T_9696d_row7_col5, #T_9696d_row7_col6, #T_9696d_row7_col7, #T_9696d_row8_col0, #T_9696d_row8_col1, #T_9696d_row8_col2, #T_9696d_row8_col3, #T_9696d_row8_col4, #T_9696d_row8_col5, #T_9696d_row8_col6, #T_9696d_row8_col7, #T_9696d_row9_col0, #T_9696d_row9_col1, #T_9696d_row9_col2, #T_9696d_row9_col3, #T_9696d_row9_col4, #T_9696d_row9_col5, #T_9696d_row9_col6, #T_9696d_row9_col7, #T_9696d_row10_col0, #T_9696d_row10_col1, #T_9696d_row10_col2, #T_9696d_row10_col3, #T_9696d_row10_col4, #T_9696d_row10_col5, #T_9696d_row10_col6, #T_9696d_row10_col7, #T_9696d_row11_col0, #T_9696d_row11_col1, #T_9696d_row11_col2, #T_9696d_row11_col3, #T_9696d_row11_col4, #T_9696d_row11_col5, #T_9696d_row11_col6, #T_9696d_row11_col7, #T_9696d_row12_col0, #T_9696d_row12_col1, #T_9696d_row12_col2, #T_9696d_row12_col4, #T_9696d_row12_col5, #T_9696d_row12_col6, #T_9696d_row12_col7, #T_9696d_row13_col0, #T_9696d_row13_col1, #T_9696d_row13_col2, #T_9696d_row13_col3, #T_9696d_row13_col4, #T_9696d_row13_col5, #T_9696d_row13_col6, #T_9696d_row13_col7, #T_9696d_row14_col0, #T_9696d_row14_col1, #T_9696d_row14_col2, #T_9696d_row14_col3, #T_9696d_row14_col4, #T_9696d_row14_col5, #T_9696d_row14_col6, #T_9696d_row14_col7, #T_9696d_row15_col0, #T_9696d_row15_col1, #T_9696d_row15_col2, #T_9696d_row15_col3, #T_9696d_row15_col4, #T_9696d_row15_col5, #T_9696d_row15_col6, #T_9696d_row15_col7 {
#   text-align: left;
# }
# #T_9696d_row0_col1, #T_9696d_row0_col2, #T_9696d_row0_col4, #T_9696d_row0_col5, #T_9696d_row0_col6, #T_9696d_row0_col7, #T_9696d_row12_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_9696d_row0_col8, #T_9696d_row1_col8, #T_9696d_row2_col8, #T_9696d_row3_col8, #T_9696d_row4_col8, #T_9696d_row5_col8, #T_9696d_row6_col8, #T_9696d_row7_col8, #T_9696d_row8_col8, #T_9696d_row9_col8, #T_9696d_row11_col8, #T_9696d_row12_col8, #T_9696d_row13_col8, #T_9696d_row14_col8, #T_9696d_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_9696d_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_9696d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9696d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9696d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_9696d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_9696d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_9696d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_9696d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_9696d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_9696d_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_9696d_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9696d_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_9696d_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_9696d_row0_col1" class="data row0 col1" >0.7527</td>
#       <td id="T_9696d_row0_col2" class="data row0 col2" >0.8088</td>
#       <td id="T_9696d_row0_col3" class="data row0 col3" >0.7667</td>
#       <td id="T_9696d_row0_col4" class="data row0 col4" >0.8270</td>
#       <td id="T_9696d_row0_col5" class="data row0 col5" >0.7581</td>
#       <td id="T_9696d_row0_col6" class="data row0 col6" >0.5176</td>
#       <td id="T_9696d_row0_col7" class="data row0 col7" >0.5651</td>
#       <td id="T_9696d_row0_col8" class="data row0 col8" >0.1140</td>
#     </tr>
#     <tr>
#       <th id="T_9696d_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_9696d_row1_col0" class="data row1 col0" >CatBoost Classifier</td>
#       <td id="T_9696d_row1_col1" class="data row1 col1" >0.7109</td>
#       <td id="T_9696d_row1_col2" class="data row1 col2" >0.7833</td>
#       <td id="T_9696d_row1_col3" class="data row1 col3" >0.7933</td>
#       <td id="T_9696d_row1_col4" class="data row1 col4" >0.7275</td>
#       <td id="T_9696d_row1_col5" class="data row1 col5" >0.7454</td>
#       <td id="T_9696d_row1_col6" class="data row1 col6" >0.4124</td>
#       <td id="T_9696d_row1_col7" class="data row1 col7" >0.4424</td>
#       <td id="T_9696d_row1_col8" class="data row1 col8" >0.9290</td>
#     </tr>
#     <tr>
#       <th id="T_9696d_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_9696d_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_9696d_row2_col1" class="data row2 col1" >0.6727</td>
#       <td id="T_9696d_row2_col2" class="data row2 col2" >0.7882</td>
#       <td id="T_9696d_row2_col3" class="data row2 col3" >0.7800</td>
#       <td id="T_9696d_row2_col4" class="data row2 col4" >0.6858</td>
#       <td id="T_9696d_row2_col5" class="data row2 col5" >0.7160</td>
#       <td id="T_9696d_row2_col6" class="data row2 col6" >0.3304</td>
#       <td id="T_9696d_row2_col7" class="data row2 col7" >0.3653</td>
#       <td id="T_9696d_row2_col8" class="data row2 col8" >0.1220</td>
#     </tr>
#     <tr>
#       <th id="T_9696d_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_9696d_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_9696d_row3_col1" class="data row3 col1" >0.6727</td>
#       <td id="T_9696d_row3_col2" class="data row3 col2" >0.7325</td>
#       <td id="T_9696d_row3_col3" class="data row3 col3" >0.7733</td>
#       <td id="T_9696d_row3_col4" class="data row3 col4" >0.6876</td>
#       <td id="T_9696d_row3_col5" class="data row3 col5" >0.7084</td>
#       <td id="T_9696d_row3_col6" class="data row3 col6" >0.3291</td>
#       <td id="T_9696d_row3_col7" class="data row3 col7" >0.3669</td>
#       <td id="T_9696d_row3_col8" class="data row3 col8" >0.1120</td>
#     </tr>
#     <tr>
#       <th id="T_9696d_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_9696d_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_9696d_row4_col1" class="data row4 col1" >0.6645</td>
#       <td id="T_9696d_row4_col2" class="data row4 col2" >0.7763</td>
#       <td id="T_9696d_row4_col3" class="data row4 col3" >0.7233</td>
#       <td id="T_9696d_row4_col4" class="data row4 col4" >0.7012</td>
#       <td id="T_9696d_row4_col5" class="data row4 col5" >0.6931</td>
#       <td id="T_9696d_row4_col6" class="data row4 col6" >0.3181</td>
#       <td id="T_9696d_row4_col7" class="data row4 col7" >0.3445</td>
#       <td id="T_9696d_row4_col8" class="data row4 col8" >0.0810</td>
#     </tr>
#     <tr>
#       <th id="T_9696d_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_9696d_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_9696d_row5_col1" class="data row5 col1" >0.6436</td>
#       <td id="T_9696d_row5_col2" class="data
# Processing:   0%|          | 0/84 [00:00<?, ?it/s]
